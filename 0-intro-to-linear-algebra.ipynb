# %% [markdown]
# <a href="https://colab.research.google.com/github/AhsenRiaz/Linear-Algebra-For-ML/blob/main/0-intro-to-linear-algebra.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
t = np.linspace(0,40,1000)

# Distance travelled by robber
d_r = 2.5 * t
# Distance travelled by sherif
d_s = 3 * (t-5)
# create the plot
fig, ax = plt.subplots()
plt.title("A bank robber caught")
plt.xlabel("time in minutes")
plt.ylabel("distance in kn")
ax.set_xlim([0, 40])
ax.set_ylim([0, 100])
ax.plot(t, d_r, c='green')
ax.plot(t, d_s, c='brown')
plt.axvline(x=30, color='purple', linestyle='--')
_= plt.axhline(y=75, color='purple', linestyle='--')
